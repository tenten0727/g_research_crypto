# %%
import pandas as pd 
data_path = '../input/'
train = pd.read_pickle(data_path+'/train.pkl')
train.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 4  1514764860         7    5.0     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8770   121.087310     25.891363 -0.008264

# %%
tmp_num = train.groupby('Asset_ID').timestamp.count()
tmp_num.head()
# Out:
# Asset_ID
# 0    1942619
# 1    1956282
# 2    1953537
# 3    1791867
# 4    1156866
# Name: timestamp, dtype: int64

# %%
indices = []
for i in train.Asset_ID.unique():
    indices += train[train.Asset_ID==i].iloc[-30*24*60:].index.values.tolist()
indices.sort()
indices
# Out:
# [23631554,
#  23631568,
#  23631582,
#  23631596,
#  23631610,
#  23631624,
#  23631638,
#  23631652,
#  23631666,
#  23631680,
#  23631694,
#  23631708,
#  23631722,
#  23631736,
#  23631750,
#  23631764,
#  23631778,
#  23631792,
#  23631806,
#  23631820,
#  23631834,
#  23631848,
#  23631862,
#  23631876,
#  23631890,
#  23631904,
#  23631916,
#  23631918,
#  23631930,
#  23631932,
#  23631938,
#  23631944,
#  23631946,
#  23631952,
#  23631958,
#  23631960,
#  23631966,
#  23631972,
#  23631974,
#  23631977,
#  23631980,
#  23631986,
#  23631988,
#  23631991,
#  23631994,
#  23632000,
#  23632002,
#  23632005,
#  23632008,
#  23632014,
#  23632016,
#  23632019,
#  23632022,
#  23632028,
#  23632030,
#  23632033,
#  23632036,
#  23632042,
#  23632044,
#  23632047,
#  23632050,
#  23632056,
#  23632058,
#  23632059,
#  23632061,
#  23632064,
#  23632070,
#  23632072,
#  23632073,
#  23632075,
#  23632076,
#  23632077,
#  23632078,
#  23632079,
#  23632080,
#  23632081,
# ...

# %%
train.loc[indices].head(20)
# Out:
#            timestamp  Asset_ID  Count         Open       High        Low  \
# 23631554  1629588120        10   25.0  3916.515540  3919.4000  3910.5770
# 23631568  1629588180        10   16.0  3913.632733  3917.7400  3909.1500
# 23631582  1629588240        10   13.0  3907.506733  3910.0400  3904.2000
# 23631596  1629588300        10    9.0  3905.260000  3907.6500  3904.6300
# 23631610  1629588360        10   11.0  3908.086750  3909.7179  3905.7500
# 23631624  1629588420        10   25.0  3904.893150  3908.6400  3899.9200
# 23631638  1629588480        10   77.0  3901.380125  3902.9405  3889.7300
# 23631652  1629588540        10   21.0  3900.866100  3903.9300  3898.8700
# 23631666  1629588600        10   19.0  3900.581200  3902.2736  3894.9700
# 23631680  1629588660        10   18.0  3900.488250  3904.9540  3900.2000
# 23631694  1629588720        10   14.0  3903.038833  3906.4900  3900.7765
# 23631708  1629588780        10   27.0  3905.415950  3905.6600  3898.3600
# ...

# %%
list = [1, 2, 3, 4, 5, 6]
list[-4:]
# Out:
# [3, 4, 5, 6]

# %%
history = pd.DataFrame(index=[])

# %%
history = pd.concat([history, train.iloc[:4]]) if history.shape[0] != 0 else train.iloc[:4]
history.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 0   2374.5900    19.233005   2373.116392 -0.004218
