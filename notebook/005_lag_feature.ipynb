# %%
import pandas as pd 
data_path = '../input/'
train = pd.read_pickle(data_path+'/train.pkl')
train.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 4  1514764860         7    5.0     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8770   121.087310     25.891363 -0.008264

# %%
train['Close_lag_1'] = train.groupby('Asset_ID').Close.shift(1)
train.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 4  1514764860         7    5.0     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target  Close_lag_1
# 0   2374.5900    19.233005   2373.116392 -0.004218          NaN
# 1      8.5300    78.380000      8.530000 -0.014399          NaN
# 2  13850.1760    31.550062  13827.062093 -0.014643          NaN
# 3      7.6576  6626.713370      7.657713 -0.013922          NaN
# 4     25.8770   121.087310     25.891363 -0.008264          NaN

# %% [markdown]
# closeがopenと必ず一致する訳ではない

# %%
train[train.Close_lag_1 == train.Open]
# Out:
#            timestamp  Asset_ID   Count         Open       High        Low  \
# 9         1514764920         0     7.0     8.530000     8.5300     8.5145
# 13        1514764920         6   192.0   738.507500   745.1400   732.4900
# 35        1514765100         5    19.0     7.635800     7.6358     7.6100
# 41        1514765160         0    89.0     8.456000     8.4560     8.3999
# 49        1514765220         0    20.0     8.400000     8.4000     8.3800
# ...              ...       ...     ...          ...        ...        ...
# 24235856  1632178380         0   556.0   365.207500   365.6000   364.4000
# 24236094  1632179400         0   573.0   361.899500   362.3000   361.2000
# 24236206  1632179880         0   853.0   361.458000   362.7000   361.0850
# 24236421  1632180780         6  3926.0  2948.182857  2957.8400  2945.0000
# 24236472  1632181020         0   396.0   361.741500   362.1000   361.0000
#
#                 Close       Volume         VWAP    Target  Close_lag_1
# ...
