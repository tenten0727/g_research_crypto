# %%
import pandas as pd 
data_path = '../input/'

# %%
train = pd.read_pickle(data_path+'/train.pkl')

# %%
train.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 4  1514764860         7    5.0     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8770   121.087310     25.891363 -0.008264

# %%
train.describe()
# Out:
#           timestamp      Asset_ID         Count          Open          High  \
# count  2.423681e+07  2.423681e+07  2.423681e+07  2.423681e+07  2.423681e+07
# mean   1.577120e+09  6.292544e+00  2.864593e+02  1.432640e+03  1.436350e+03
# std    3.323350e+07  4.091861e+00  8.673982e+02  6.029605e+03  6.039482e+03
# min    1.514765e+09  0.000000e+00  1.000000e+00  1.170400e-03  1.195000e-03
# 25%    1.549011e+09  3.000000e+00  1.900000e+01  2.676500e-01  2.681600e-01
# 50%    1.578372e+09  6.000000e+00  6.400000e+01  1.428860e+01  1.431250e+01
# 75%    1.606198e+09  9.000000e+00  2.210000e+02  2.288743e+02  2.293000e+02
# max    1.632182e+09  1.300000e+01  1.650160e+05  6.480594e+04  6.490000e+04
#
#                 Low         Close        Volume          VWAP        Target
# count  2.423681e+07  2.423681e+07  2.423681e+07  2.423680e+07  2.348647e+07
# mean   1.429568e+03  1.432640e+03  2.868530e+05           NaN  7.121752e-06
# ...

# %%
train.shape
# Out:
# (24236806, 10)

# %%
train.to_pickle(data_path+'train.pkl')

# %%
train.tail()
# Out:
#            timestamp  Asset_ID  Count         Open         High          Low  \
# 24236801  1632182400         9  775.0   157.181571   157.250000   156.700000
# 24236802  1632182400        10   34.0  2437.065067  2438.000000  2430.226900
# 24236803  1632182400        13  380.0     0.091390     0.091527     0.091260
# 24236804  1632182400        12  177.0     0.282168     0.282438     0.281842
# 24236805  1632182400        11   48.0   232.695000   232.800000   232.240000
#
#                 Close        Volume         VWAP  Target
# 24236801   156.943857  4.663725e+03   156.994319     NaN
# 24236802  2432.907467  3.975460e+00  2434.818747     NaN
# 24236803     0.091349  2.193732e+06     0.091388     NaN
# 24236804     0.282051  1.828508e+05     0.282134     NaN
# 24236805   232.275000  1.035123e+02   232.569697     NaN

# %%
train.isnull().sum()
# Out:
# timestamp         0
# Asset_ID          0
# Count             0
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# VWAP              9
# Target       750338
# dtype: int64

# %%
train.dropna().shape
# Out:
# (23486465, 10)

# %%
train['datetime'] = pd.to_datetime(train['timestamp'], unit='s')
df_test = train[train['datetime'] >= '2021-06-13 00:00:00']
df_test
# Out:
#            timestamp  Asset_ID   Count          Open          High  \
# 22221694  1623542400         3  1201.0      1.478556      1.486030
# 22221695  1623542400         2  1020.0    580.306667    583.890000
# 22221696  1623542400         0   626.0    343.789500    345.108000
# 22221697  1623542400         1  2888.0  35554.289632  35652.464650
# 22221698  1623542400         4   433.0      0.312167      0.312600
# ...              ...       ...     ...           ...           ...
# 24236801  1632182400         9   775.0    157.181571    157.250000
# 24236802  1632182400        10    34.0   2437.065067   2438.000000
# 24236803  1632182400        13   380.0      0.091390      0.091527
# 24236804  1632182400        12   177.0      0.282168      0.282438
# 24236805  1632182400        11    48.0    232.695000    232.800000
#
#                    Low         Close        Volume          VWAP    Target  \
# 22221694      1.478000      1.483681  6.547996e+05      1.481439 -0.002594
# ...

# %%
import os
DATA_FOLDER = '../input'
asset_details = pd.read_csv(os.path.join(DATA_FOLDER, 'g-research-crypto-forecasting', 'asset_details.csv'))
weight_map_dict = dict(zip(asset_details['Asset_ID'], asset_details['Weight']))
weight_map_dict
# Out:
# {2: 2.3978952727983707,
#  0: 4.30406509320417,
#  1: 6.779921907472252,
#  5: 1.3862943611198906,
#  7: 2.079441541679836,
#  6: 5.8944028342648505,
#  9: 2.3978952727983707,
#  11: 1.6094379124341005,
#  13: 1.791759469228055,
#  12: 2.079441541679836,
#  3: 4.406719247264253,
#  8: 1.0986122886681098,
#  10: 1.0986122886681098,
#  4: 3.555348061489413}

# %%
df_test['weight'] = df_test['Asset_ID'].map(weight_map_dict)
df_test
# Out:
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/g_research_crypto/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            timestamp  Asset_ID   Count          Open          High  \
# 22221694  1623542400         3  1201.0      1.478556      1.486030
# 22221695  1623542400         2  1020.0    580.306667    583.890000
# 22221696  1623542400         0   626.0    343.789500    345.108000
# 22221697  1623542400         1  2888.0  35554.289632  35652.464650
# 22221698  1623542400         4   433.0      0.312167      0.312600
# ...              ...       ...     ...           ...           ...
# ...
