# %%
import os
import random
import pandas as pd
import numpy as np
import lightgbm as lgbm
import mlflow

import sys
sys.path.append('../input/g-research-crypto-forecasting')
import gresearch_crypto


TRAIN_CSV = '../input/g-research-crypto-forecasting/train.csv'
ASSET_DETAILS_CSV = '../input/g-research-crypto-forecasting/asset_details.csv'
RESULT_FOLDER = '../result/nb019'
if not os.path.isdir(RESULT_FOLDER):
    os.makedirs(RESULT_FOLDER)
SEED = 2021
DEBUG = False

REMOVE_LB_TEST_OVERLAPPING_DATA = True

# %%
def fix_all_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

fix_all_seeds(SEED)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2 
    dfs = []
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    dfs.append(df[col].astype(np.int8))
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    dfs.append(df[col].astype(np.int16))
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    dfs.append(df[col].astype(np.int32))
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    dfs.append(df[col].astype(np.int64) ) 
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    dfs.append(df[col].astype(np.float16))
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    dfs.append(df[col].astype(np.float32))
                else:
                    dfs.append(df[col].astype(np.float64))
        else:
            dfs.append(df[col])
    
    df_out = pd.concat(dfs, axis=1)
    if verbose:
        end_mem = df_out.memory_usage().sum() / 1024**2
        num_reduction = str(100 * (start_mem - end_mem) / start_mem)
        print(f'Mem. usage decreased to {str(end_mem)[:3]}Mb:  {num_reduction[:2]}% reduction')
    return df_out

# %%
df_train = pd.read_csv(TRAIN_CSV)
df_train.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 4  1514764860         7    5.0     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8770   121.087310     25.891363 -0.008264

# %% [markdown]
# ## Keep only values _before_ the LB test set

# %%
# Remove the future
if REMOVE_LB_TEST_OVERLAPPING_DATA:
    df_train['datetime'] = pd.to_datetime(df_train['timestamp'], unit='s')
    df_test = df_train[df_train['datetime'] >= '2021-06-13 00:00:00']
    df_test = df_test.dropna(how="any")
    df_train = df_train[df_train['datetime'] < '2021-06-13 00:00:00']
    if DEBUG:
        df_train = df_train.iloc[:100000]

# %%
df_asset_details = pd.read_csv(ASSET_DETAILS_CSV).sort_values("Asset_ID")
df_asset_details
# Out:
#     Asset_ID    Weight        Asset_Name
# 1          0  4.304065      Binance Coin
# 2          1  6.779922           Bitcoin
# 0          2  2.397895      Bitcoin Cash
# 10         3  4.406719           Cardano
# 13         4  3.555348          Dogecoin
# 3          5  1.386294            EOS.IO
# 5          6  5.894403          Ethereum
# 4          7  2.079442  Ethereum Classic
# 11         8  1.098612              IOTA
# 6          9  2.397895          Litecoin
# 12        10  1.098612             Maker
# 7         11  1.609438            Monero
# 9         12  2.079442           Stellar
# 8         13  1.791759              TRON

# %% [markdown]
# # Training

# %%
# !pip install --no-index --find-links ../input/talibbinary/talib_binary-0.4.19-cp37-cp37m-manylinux1_x86_64.whl talib-binary

# %% [markdown]
# ## Utility functions to train a model for one asset

# %%
import talib
from sklearn.preprocessing import StandardScaler
sys.path.append('../src')
from utils import eval_w_corr

# Two new features from the competition tutorial
def upper_shadow(df):
    return df['High'] - np.maximum(df['Close'], df['Open'])

def lower_shadow(df):
    return np.minimum(df['Close'], df['Open']) - df['Low']

def moving_average(a, n):
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret / n

# A utility function to build features from the original df
# It works for rows to, so we can reutilize it.
def get_features(df):
    df_feat = df[['Count', 'Open', 'High', 'Low', 'Close', 'Volume', 'VWAP', 'Asset_ID', 'Target']].copy()
    df_feat['upper_shadow'] = upper_shadow(df_feat)
    df_feat['lower_shadow'] = lower_shadow(df_feat)
    
    df_feat['ln_Close'] = np.log(df['Close'])
    
    asset_group_close = df_feat.groupby('Asset_ID')['Close']
    
    df_feat['log_return_1'] = df_feat['ln_Close'] - df_feat.groupby('Asset_ID')['ln_Close'].shift(1)
    df_feat['log_return_5'] = df_feat['ln_Close'] - df_feat.groupby('Asset_ID')['ln_Close'].shift(5)
    df_feat['log_return_15'] = df_feat['ln_Close'] - df_feat.groupby('Asset_ID')['ln_Close'].shift(15)
    df_feat['log_return_60'] = df_feat['ln_Close'] - df_feat.groupby('Asset_ID')['ln_Close'].shift(60)
    
    for i in [5, 15, 60]:
        df_feat['realized_volatility_'+str(i)] = df_feat.groupby('Asset_ID').log_return_1.transform(lambda x: x.rolling(i).std(ddof=0))
#         df_data['RV_'+str(i)+'_rank'] = df_data.groupby('timestamp')['realized_volatility_'+str(i)].transform('rank')
    
        df_feat['moving_average_'+str(i)] = asset_group_close.transform(lambda x: moving_average(x.values, i))
        df_feat['moving_std_'+str(i)] = asset_group_close.transform(lambda x: x.rolling(window=i, min_periods=1).std())
        df_feat['volume_moving_average_'+str(i)] = df_feat.groupby('Asset_ID').Volume.transform(lambda x: moving_average(x.values, i))
        df_feat['RSI_'+str(i)] = asset_group_close.transform(lambda x: talib.RSI(x.values.astype(np.float64), i))
        
        df_feat['close_div_ma_'+str(i)] = df_feat['Close'] / df_feat['moving_average_'+str(i)]
        df_feat['volume_div_ma_'+str(i)] = df_feat['Volume'] / df_feat['volume_moving_average_'+str(i)]

    # df_feat['MACD'], df_feat['MACD_signal'], df_feat['MACD_hist'] = talib.MACD(df_feat.Close.values, fastperiod=12, slowperiod=26, signalperiod=9)
    # df_feat['adx'] = talib.ADX(df_feat.High, df_feat.Low, df_feat.Close, timeperiod=14)

    df_feat = df_feat.drop(['ln_Close'], axis=1)
    
    return df_feat


def get_model_for_asset(df_train, df_test, asset_id):
    df_train = df_train[df_train["Asset_ID"] == asset_id]
    df_test = df_test[df_test["Asset_ID"] == asset_id]
    
    df_train = df_train.dropna(how="any")
    df_test = df_test.dropna(how="any")

    
    X_train, y_train = df_train.drop(['Asset_ID', 'Target'], axis=1), df_train["Target"]
    X_valid, y_valid = df_test.drop(['Asset_ID', 'Target'], axis=1), df_test["Target"]
    lgbm_train = lgbm.Dataset(X_train, y_train)
    lgbm_valid = lgbm.Dataset(X_valid, y_valid)
    weight_map_dict = dict(zip(df_asset_details['Asset_ID'], df_asset_details['Weight']))
    lgbm_train.add_w = df_train['Asset_ID'].map(weight_map_dict)
    lgbm_valid.add_w = df_test['Asset_ID'].map(weight_map_dict)
    with mlflow.start_run(experiment_id=5, nested=True):

        params = {
            "objective": "regression", 
            "metric": "rmse", 
            "boosting_type": "gbdt",
            # 'early_stopping_rounds': 20,
            'learning_rate': 0.05,
            'num_leaves': 8,
            'feature_fraction': 0.5,
            'bagging_fraction': 0.5,
            'bagging_freq': 1,
            'extra_trees': True,
            'seed': 55
        }
        mlflow.log_params(params)

        category_feature = []
        model = lgbm.train(params=params,
            train_set=lgbm_train,
            valid_sets=[lgbm_train, lgbm_valid],
            num_boost_round=50,
            verbose_eval=10,
            feval=eval_w_corr,
            categorical_feature = category_feature,
        )
    
    return model

# %% [markdown]
# ## Loop over all assets

# %%
def weighted_correlation(a, b, weights):
  w = np.ravel(weights)
  a = np.ravel(a)
  b = np.ravel(b)

  sum_w = np.sum(w)
  mean_a = np.sum(a * w) / sum_w
  mean_b = np.sum(b * w) / sum_w
  var_a = np.sum(w * np.square(a - mean_a)) / sum_w
  var_b = np.sum(w * np.square(b - mean_b)) / sum_w

  cov = np.sum((a * b * w)) / np.sum(w) - mean_a * mean_b
  corr = cov / np.sqrt(var_a * var_b)

  return corr

# %%
df_train = get_features(df_train)
df_test = get_features(df_test)
print(df_train.columns)
# Out:
# Index(['Count', 'Open', 'High', 'Low', 'Close', 'Volume', 'VWAP', 'Asset_ID',
#        'Target', 'upper_shadow', 'lower_shadow', 'log_return_1',
#        'log_return_5', 'log_return_15', 'log_return_60',
#        'realized_volatility_5', 'moving_average_5', 'moving_std_5',
#        'volume_moving_average_5', 'RSI_5', 'close_div_ma_5', 'volume_div_ma_5',
#        'realized_volatility_15', 'moving_average_15', 'moving_std_15',
#        'volume_moving_average_15', 'RSI_15', 'close_div_ma_15',
#        'volume_div_ma_15', 'realized_volatility_60', 'moving_average_60',
#        'moving_std_60', 'volume_moving_average_60', 'RSI_60',
#        'close_div_ma_60', 'volume_div_ma_60'],
#       dtype='object')

# %%
Xs = {}
ys = {}
models = {}

y_valids = []
mlflow.lightgbm.autolog()
mlflow.set_tracking_uri('../src/mlruns/')
with mlflow.start_run(experiment_id=5):
    for asset_id, asset_name in zip(df_asset_details['Asset_ID'], df_asset_details['Asset_Name']):
        print(f"Training model for {asset_name:<16} (ID={asset_id:<2})")
        
        model = get_model_for_asset(df_train, df_test, asset_id)
        models[asset_id] = model
        
        X_valid = df_test[df_test['Asset_ID'] == asset_id].drop(['Target', 'Asset_ID'], axis=1)
        y_valid = df_test.loc[df_test['Asset_ID'] == asset_id, ['Target']]
        weight_map_dict = dict(zip(df_asset_details['Asset_ID'], df_asset_details['Weight']))
        y_valid['Weight'] = weight_map_dict[asset_id]
        y_valid['Pred'] = model.predict(X_valid)
        
        y_valids.append(y_valid)
        model.save_model(os.path.join(RESULT_FOLDER, f'model{asset_id}.lgb'), num_iteration=model.best_iteration)

    y_valids = pd.concat(y_valids)

    metric = weighted_correlation(y_valids['Pred'], y_valids['Target'], y_valids['Weight'])
    print(f"overall, wcorr: {metric}")
    mlflow.log_metric('score', metric)

del X_valid, y_valid, y_valids
# Out:
# Training model for Binance Coin     (ID=0 )
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/g_research_crypto/lib/python3.7/site-packages/lightgbm/basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/g_research_crypto/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.196295 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1785283, number of used features: 34
# [LightGBM] [Info] Start training from score 0.000034
# [10]	training's rmse: 0.00561279	training's eval_wcorr: 0.0602146	valid_1's rmse: 0.00268469	valid_1's eval_wcorr: 0.0357382
# [20]	training's rmse: 0.00560747	training's eval_wcorr: 0.0906645	valid_1's rmse: 0.00268417	valid_1's eval_wcorr: 0.0393373
# [30]	training's rmse: 0.00560321	training's eval_wcorr: 0.0998958	valid_1's rmse: 0.00268399	valid_1's eval_wcorr: 0.0363938
# [40]	training's rmse: 0.00560161	training's eval_wcorr: 0.101239	valid_1's rmse: 0.00268396	valid_1's eval_wcorr: 0.0342787
# [50]	training's rmse: 0.00560014	training's eval_wcorr: 0.102862	valid_1's rmse: 0.00268407	valid_1's eval_wcorr: 0.0310443
# Training model for Bitcoin          (ID=1 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.183294 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1811936, number of used features: 34
# [LightGBM] [Info] Start training from score -0.000002
# [10]	training's rmse: 0.00204183	training's eval_wcorr: 0.0614737	valid_1's rmse: 0.00159018	valid_1's eval_wcorr: 0.0281873
# [20]	training's rmse: 0.00204075	training's eval_wcorr: 0.0664971	valid_1's rmse: 0.00158984	valid_1's eval_wcorr: 0.0371805
# [30]	training's rmse: 0.00203985	training's eval_wcorr: 0.0708317	valid_1's rmse: 0.00158973	valid_1's eval_wcorr: 0.0350112
# [40]	training's rmse: 0.00203916	training's eval_wcorr: 0.0748512	valid_1's rmse: 0.00158977	valid_1's eval_wcorr: 0.0327642
# [50]	training's rmse: 0.00203859	training's eval_wcorr: 0.0783536	valid_1's rmse: 0.00158978	valid_1's eval_wcorr: 0.0325532
# Training model for Bitcoin Cash     (ID=2 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.185502 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1804634, number of used features: 34
# [LightGBM] [Info] Start training from score -0.000005
# [10]	training's rmse: 0.00669581	training's eval_wcorr: 0.0802789	valid_1's rmse: 0.0021726	valid_1's eval_wcorr: 0.0126675
# [20]	training's rmse: 0.00669091	training's eval_wcorr: 0.0858943	valid_1's rmse: 0.00217222	valid_1's eval_wcorr: 0.0236672
# [30]	training's rmse: 0.00668826	training's eval_wcorr: 0.0872084	valid_1's rmse: 0.00217211	valid_1's eval_wcorr: 0.026254
# [40]	training's rmse: 0.00668602	training's eval_wcorr: 0.091934	valid_1's rmse: 0.00217202	valid_1's eval_wcorr: 0.0277006
# [50]	training's rmse: 0.00668138	training's eval_wcorr: 0.100542	valid_1's rmse: 0.00217204	valid_1's eval_wcorr: 0.0275153
# Training model for Cardano          (ID=3 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.196480 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1629095, number of used features: 34
# [LightGBM] [Info] Start training from score -0.000000
# [10]	training's rmse: 0.00461595	training's eval_wcorr: 0.0543508	valid_1's rmse: 0.00302023	valid_1's eval_wcorr: 0.0653882
# [20]	training's rmse: 0.00461399	training's eval_wcorr: 0.0605254	valid_1's rmse: 0.00301876	valid_1's eval_wcorr: 0.0659935
# [30]	training's rmse: 0.00461265	training's eval_wcorr: 0.0646317	valid_1's rmse: 0.00301838	valid_1's eval_wcorr: 0.0647522
# [40]	training's rmse: 0.00461182	training's eval_wcorr: 0.0661918	valid_1's rmse: 0.00301798	valid_1's eval_wcorr: 0.0659246
# [50]	training's rmse: 0.00461073	training's eval_wcorr: 0.0702546	valid_1's rmse: 0.00301802	valid_1's eval_wcorr: 0.0652507
# Training model for Dogecoin         (ID=4 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.129293 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 867851, number of used features: 34
# [LightGBM] [Info] Start training from score 0.000057
# [10]	training's rmse: 0.00862363	training's eval_wcorr: 0.0993047	valid_1's rmse: 0.00378188	valid_1's eval_wcorr: 0.0105427
# [20]	training's rmse: 0.00861678	training's eval_wcorr: 0.10569	valid_1's rmse: 0.00377973	valid_1's eval_wcorr: 0.0330958
# [30]	training's rmse: 0.00861082	training's eval_wcorr: 0.111594	valid_1's rmse: 0.00377711	valid_1's eval_wcorr: 0.049866
# [40]	training's rmse: 0.0086057	training's eval_wcorr: 0.117676	valid_1's rmse: 0.00377747	valid_1's eval_wcorr: 0.0493593
# [50]	training's rmse: 0.00860073	training's eval_wcorr: 0.122451	valid_1's rmse: 0.0037777	valid_1's eval_wcorr: 0.0494075
# Training model for EOS.IO           (ID=5 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.208377 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1808805, number of used features: 34
# [LightGBM] [Info] Start training from score -0.000001
# [10]	training's rmse: 0.00494532	training's eval_wcorr: 0.0530103	valid_1's rmse: 0.00289476	valid_1's eval_wcorr: 0.0237658
# [20]	training's rmse: 0.00494301	training's eval_wcorr: 0.060298	valid_1's rmse: 0.00289446	valid_1's eval_wcorr: 0.0264096
# [30]	training's rmse: 0.00494093	training's eval_wcorr: 0.0666895	valid_1's rmse: 0.00289474	valid_1's eval_wcorr: 0.0241781
# [40]	training's rmse: 0.00493965	training's eval_wcorr: 0.0702836	valid_1's rmse: 0.00289484	valid_1's eval_wcorr: 0.0245634
# [50]	training's rmse: 0.0049384	training's eval_wcorr: 0.0732386	valid_1's rmse: 0.00289486	valid_1's eval_wcorr: 0.0257537
# Training model for Ethereum         (ID=6 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.188444 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1811818, number of used features: 34
# [LightGBM] [Info] Start training from score -0.000002
# [10]	training's rmse: 0.00254024	training's eval_wcorr: 0.0657862	valid_1's rmse: 0.00180541	valid_1's eval_wcorr: -0.00580965
# [20]	training's rmse: 0.00253894	training's eval_wcorr: 0.06793	valid_1's rmse: 0.00180561	valid_1's eval_wcorr: -0.00855381
# [30]	training's rmse: 0.00253772	training's eval_wcorr: 0.0727108	valid_1's rmse: 0.00180585	valid_1's eval_wcorr: -0.00829717
# [40]	training's rmse: 0.00253688	training's eval_wcorr: 0.0750731	valid_1's rmse: 0.00180591	valid_1's eval_wcorr: -0.00496245
# [50]	training's rmse: 0.00253618	training's eval_wcorr: 0.0775314	valid_1's rmse: 0.00180605	valid_1's eval_wcorr: -0.00361507
# Training model for Ethereum Classic (ID=7 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.194724 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1797766, number of used features: 34
# [LightGBM] [Info] Start training from score 0.000042
# [10]	training's rmse: 0.00927189	training's eval_wcorr: 0.0648771	valid_1's rmse: 0.00329128	valid_1's eval_wcorr: 0.023728
# [20]	training's rmse: 0.00926679	training's eval_wcorr: 0.0690736	valid_1's rmse: 0.00329182	valid_1's eval_wcorr: 0.0109671
# [30]	training's rmse: 0.00926307	training's eval_wcorr: 0.0718309	valid_1's rmse: 0.00329096	valid_1's eval_wcorr: 0.0237238
# [40]	training's rmse: 0.00926043	training's eval_wcorr: 0.0742105	valid_1's rmse: 0.00329162	valid_1's eval_wcorr: 0.0172874
# [50]	training's rmse: 0.00925807	training's eval_wcorr: 0.0768989	valid_1's rmse: 0.00329161	valid_1's eval_wcorr: 0.0189594
# Training model for IOTA             (ID=8 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.157661 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1255713, number of used features: 34
# [LightGBM] [Info] Start training from score 0.000009
# [10]	training's rmse: 0.00750833	training's eval_wcorr: 0.0607107	valid_1's rmse: 0.0115563	valid_1's eval_wcorr: 0.0255229
# [20]	training's rmse: 0.00750588	training's eval_wcorr: 0.0655507	valid_1's rmse: 0.0115558	valid_1's eval_wcorr: 0.0249475
# [30]	training's rmse: 0.00750383	training's eval_wcorr: 0.0702402	valid_1's rmse: 0.0115554	valid_1's eval_wcorr: 0.026556
# [40]	training's rmse: 0.0075009	training's eval_wcorr: 0.0809044	valid_1's rmse: 0.0115544	valid_1's eval_wcorr: 0.0317097
# [50]	training's rmse: 0.00749761	training's eval_wcorr: 0.0899392	valid_1's rmse: 0.0115538	valid_1's eval_wcorr: 0.0332228
# Training model for Litecoin         (ID=9 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.182622 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1811467, number of used features: 34
# [LightGBM] [Info] Start training from score -0.000014
# [10]	training's rmse: 0.00358877	training's eval_wcorr: 0.0651562	valid_1's rmse: 0.00301978	valid_1's eval_wcorr: 0.0257246
# [20]	training's rmse: 0.00358617	training's eval_wcorr: 0.0724619	valid_1's rmse: 0.00301967	valid_1's eval_wcorr: 0.0255964
# [30]	training's rmse: 0.00358457	training's eval_wcorr: 0.0753368	valid_1's rmse: 0.00301991	valid_1's eval_wcorr: 0.0248808
# [40]	training's rmse: 0.00358327	training's eval_wcorr: 0.0787386	valid_1's rmse: 0.00301979	valid_1's eval_wcorr: 0.0274388
# [50]	training's rmse: 0.00358237	training's eval_wcorr: 0.0806067	valid_1's rmse: 0.00301998	valid_1's eval_wcorr: 0.0274816
# Training model for Maker            (ID=10)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.109662 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 487817, number of used features: 34
# [LightGBM] [Info] Start training from score 0.000003
# [10]	training's rmse: 0.00619313	training's eval_wcorr: 0.081373	valid_1's rmse: 0.00523272	valid_1's eval_wcorr: 0.0349218
# [20]	training's rmse: 0.00618741	training's eval_wcorr: 0.0876323	valid_1's rmse: 0.00523141	valid_1's eval_wcorr: 0.0420443
# [30]	training's rmse: 0.00618336	training's eval_wcorr: 0.0941514	valid_1's rmse: 0.00523055	valid_1's eval_wcorr: 0.0446443
# [40]	training's rmse: 0.00617984	training's eval_wcorr: 0.0982872	valid_1's rmse: 0.00523028	valid_1's eval_wcorr: 0.0442682
# [50]	training's rmse: 0.00617605	training's eval_wcorr: 0.105576	valid_1's rmse: 0.00522957	valid_1's eval_wcorr: 0.0483325
# Training model for Monero           (ID=11)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.167878 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1317757, number of used features: 34
# [LightGBM] [Info] Start training from score 0.000008
# [10]	training's rmse: 0.00688077	training's eval_wcorr: 0.0491109	valid_1's rmse: 0.00397619	valid_1's eval_wcorr: -0.00616302
# [20]	training's rmse: 0.00687818	training's eval_wcorr: 0.0636763	valid_1's rmse: 0.00397694	valid_1's eval_wcorr: -0.0161304
# [30]	training's rmse: 0.00687489	training's eval_wcorr: 0.080091	valid_1's rmse: 0.00397748	valid_1's eval_wcorr: -0.014601
# [40]	training's rmse: 0.00687311	training's eval_wcorr: 0.0845655	valid_1's rmse: 0.00397796	valid_1's eval_wcorr: -0.014291
# [50]	training's rmse: 0.00687176	training's eval_wcorr: 0.0866558	valid_1's rmse: 0.00397813	valid_1's eval_wcorr: -0.012638
# Training model for Stellar          (ID=12)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.183145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1572948, number of used features: 34
# [LightGBM] [Info] Start training from score -0.000009
# [10]	training's rmse: 0.00536485	training's eval_wcorr: 0.0557597	valid_1's rmse: 0.00302579	valid_1's eval_wcorr: -0.019801
# [20]	training's rmse: 0.00536268	training's eval_wcorr: 0.0652806	valid_1's rmse: 0.00302642	valid_1's eval_wcorr: -0.0179024
# [30]	training's rmse: 0.00536106	training's eval_wcorr: 0.0697295	valid_1's rmse: 0.00302685	valid_1's eval_wcorr: -0.0142261
# [40]	training's rmse: 0.00535938	training's eval_wcorr: 0.0748009	valid_1's rmse: 0.00302722	valid_1's eval_wcorr: -0.0102599
# [50]	training's rmse: 0.00535817	training's eval_wcorr: 0.0770365	valid_1's rmse: 0.00302773	valid_1's eval_wcorr: -0.00886494
# Training model for TRON             (ID=13)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.179183 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8670
# [LightGBM] [Info] Number of data points in the train set: 1709526, number of used features: 34
# [LightGBM] [Info] Start training from score 0.000008
# [10]	training's rmse: 0.00505355	training's eval_wcorr: 0.0549895	valid_1's rmse: 0.00285151	valid_1's eval_wcorr: 0.0560106
# [20]	training's rmse: 0.00505182	training's eval_wcorr: 0.0616221	valid_1's rmse: 0.0028519	valid_1's eval_wcorr: 0.0358486
# [30]	training's rmse: 0.0050504	training's eval_wcorr: 0.0705236	valid_1's rmse: 0.0028519	valid_1's eval_wcorr: 0.0318991
# [40]	training's rmse: 0.00504898	training's eval_wcorr: 0.0757716	valid_1's rmse: 0.00285195	valid_1's eval_wcorr: 0.030312
# [50]	training's rmse: 0.00504731	training's eval_wcorr: 0.0823156	valid_1's rmse: 0.00285208	valid_1's eval_wcorr: 0.0288184
# overall, wcorr: 0.02897671609305679

# %%
raise ValueError("stop!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1336871/2431878494.py in <module>
# ----> 1 raise ValueError("stop!")
#
# ValueError: stop!

# %% [markdown]
# # Predict & submit
#
# References: [Detailed API Introduction](https://www.kaggle.com/sohier/detailed-api-introduction)
#
# Something that helped me understand this iterator was adding a pdb checkpoint inside of the for loop:
#
# ```python
# import pdb; pdb.set_trace()
# ```
#
# See [Python Debugging With Pdb](https://realpython.com/python-debugging-pdb/) if you want to use it and you don't know how to.

# %%
import time
history = pd.DataFrame()
max_lookback = 60

env = gresearch_crypto.make_env()
iter_test = env.iter_test()

start = time.time()
for i, (df_test, df_pred) in enumerate(iter_test):
    history = pd.concat([history, df_test]).reset_index(drop=True)

    for j , row in df_test.iterrows():
        model = models[row['Asset_ID']]
        x_test = get_features(history[history['Asset_ID'] == row['Asset_ID']]).reset_index(drop=True)
        y_pred = model.predict([x_test.iloc[-1]])[0]
        
        df_pred.loc[df_pred['row_id'] == row['row_id'], 'Target'] = y_pred
        
        # Print just one sample row to get a feeling of what it looks like
        if i == 0 and j == 0:
            display(x_test)

    # Display the first prediction dataframe
    if i == 0:
        display(df_pred)
    history = history.sort_values(by='row_id')
    history = history.iloc[-(max_lookback*14+100):]
    
    # Send submissions
    env.predict(df_pred)
end = time.time()
end-start

# %% [markdown]
# # df_train and df_test overlap

# %%
# df_test = pd.concat(all_df_test)
# df_test['datetime'] = pd.to_datetime(df_test['timestamp'], unit='s')
# df_train['datetime'] = pd.to_datetime(df_train['timestamp'], unit='s')

# %%
# df_train['datetime'].max()

# %%
# df_test['datetime'].min()
