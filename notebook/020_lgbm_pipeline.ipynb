# %%
import os
import random
import pandas as pd
import numpy as np
import lightgbm as lgbm
import mlflow

import sys
sys.path.append('../input/g-research-crypto-forecasting')
import gresearch_crypto


TRAIN_CSV = '../input/g-research-crypto-forecasting/train.csv'
ASSET_DETAILS_CSV = '../input/g-research-crypto-forecasting/asset_details.csv'
RESULT_FOLDER = '../result/nb020'
if not os.path.isdir(RESULT_FOLDER):
    os.makedirs(RESULT_FOLDER)
SEED = 2021
DEBUG = False

REMOVE_LB_TEST_OVERLAPPING_DATA = True

# %%
def fix_all_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

fix_all_seeds(SEED)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2 
    dfs = []
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    dfs.append(df[col].astype(np.int8))
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    dfs.append(df[col].astype(np.int16))
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    dfs.append(df[col].astype(np.int32))
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    dfs.append(df[col].astype(np.int64) ) 
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    dfs.append(df[col].astype(np.float16))
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    dfs.append(df[col].astype(np.float32))
                else:
                    dfs.append(df[col].astype(np.float64))
        else:
            dfs.append(df[col])
    
    df_out = pd.concat(dfs, axis=1)
    if verbose:
        end_mem = df_out.memory_usage().sum() / 1024**2
        num_reduction = str(100 * (start_mem - end_mem) / start_mem)
        print(f'Mem. usage decreased to {str(end_mem)[:3]}Mb:  {num_reduction[:2]}% reduction')
    return df_out

# %%
df_train = pd.read_csv(TRAIN_CSV)
df_train.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 4  1514764860         7    5.0     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8770   121.087310     25.891363 -0.008264

# %% [markdown]
# ## Keep only values _before_ the LB test set

# %%
# Remove the future
if REMOVE_LB_TEST_OVERLAPPING_DATA:
    df_train['datetime'] = pd.to_datetime(df_train['timestamp'], unit='s')
    df_test = df_train[df_train['datetime'] >= '2021-06-13 00:00:00']
    df_test = df_test.dropna(how="any")
    df_train = df_train[df_train['datetime'] < '2021-06-13 00:00:00']
    if DEBUG:
        df_train = df_train.iloc[:100000]

# %%
df_asset_details = pd.read_csv(ASSET_DETAILS_CSV).sort_values("Asset_ID")
df_asset_details
# Out:
#     Asset_ID    Weight        Asset_Name
# 1          0  4.304065      Binance Coin
# 2          1  6.779922           Bitcoin
# 0          2  2.397895      Bitcoin Cash
# 10         3  4.406719           Cardano
# 13         4  3.555348          Dogecoin
# 3          5  1.386294            EOS.IO
# 5          6  5.894403          Ethereum
# 4          7  2.079442  Ethereum Classic
# 11         8  1.098612              IOTA
# 6          9  2.397895          Litecoin
# 12        10  1.098612             Maker
# 7         11  1.609438            Monero
# 9         12  2.079442           Stellar
# 8         13  1.791759              TRON

# %% [markdown]
# # Training

# %%
# !pip install --no-index --find-links ../input/talibbinary/talib_binary-0.4.19-cp37-cp37m-manylinux1_x86_64.whl talib-binary

# %% [markdown]
# ## Utility functions to train a model for one asset

# %%
import talib
from sklearn.preprocessing import StandardScaler
sys.path.append('../src')
from utils import eval_w_corr

# Two new features from the competition tutorial
def upper_shadow(df):
    return df['High'] - np.maximum(df['Close'], df['Open'])

def lower_shadow(df):
    return np.minimum(df['Close'], df['Open']) - df['Low']

def moving_average(a, n):
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret / n

# A utility function to build features from the original df
# It works for rows to, so we can reutilize it.
def get_features(df):
    df_feat = df[['Count', 'Open', 'High', 'Low', 'Close', 'Volume', 'VWAP', 'Asset_ID', 'Target', 'timestamp']].copy()
    df_feat['upper_shadow'] = upper_shadow(df_feat)
    df_feat['lower_shadow'] = lower_shadow(df_feat)
    
    df_feat['ln_Close'] = np.log(df['Close'])
    
    asset_group_close = df_feat.groupby('Asset_ID')['Close']

    df_feat['high_low_div'] = df_feat['High'] / df_feat['Low']
    df_feat['open_close_div'] = df_feat['Open'] / df_feat['Close']

    df_feat['hlco_ration'] = (df_feat["Open"] - df_feat["Close"]) / (df_feat["High"] - df_feat["Low"])
    
    df_feat['log_return_1'] = df_feat['ln_Close'] - df_feat.groupby('Asset_ID')['ln_Close'].shift(1)
    df_feat['log_return_5'] = df_feat['ln_Close'] - df_feat.groupby('Asset_ID')['ln_Close'].shift(5)
    df_feat['log_return_15'] = df_feat['ln_Close'] - df_feat.groupby('Asset_ID')['ln_Close'].shift(15)
    df_feat['log_return_60'] = df_feat['ln_Close'] - df_feat.groupby('Asset_ID')['ln_Close'].shift(60)
    
    for i in [5, 15, 60]:
        df_feat['realized_volatility_'+str(i)] = df_feat.groupby('Asset_ID').log_return_1.transform(lambda x: x.rolling(i).std(ddof=0))
#         df_data['RV_'+str(i)+'_rank'] = df_data.groupby('timestamp')['realized_volatility_'+str(i)].transform('rank')
    
        df_feat['moving_average_'+str(i)] = asset_group_close.transform(lambda x: moving_average(x.values, i))
        df_feat['moving_std_'+str(i)] = asset_group_close.transform(lambda x: x.rolling(window=i, min_periods=1).std())
        df_feat['volume_moving_average_'+str(i)] = df_feat.groupby('Asset_ID').Volume.transform(lambda x: moving_average(x.values, i))
        df_feat['RSI_'+str(i)] = asset_group_close.transform(lambda x: talib.RSI(x.values.astype(np.float64), i))
        
        df_feat['close_div_ma_'+str(i)] = df_feat['Close'] / df_feat['moving_average_'+str(i)]
        df_feat['volume_div_ma_'+str(i)] = df_feat['Volume'] / df_feat['volume_moving_average_'+str(i)]

    # df_feat['MACD'], df_feat['MACD_signal'], df_feat['MACD_hist'] = talib.MACD(df_feat.Close.values, fastperiod=12, slowperiod=26, signalperiod=9)
    # df_feat['adx'] = talib.ADX(df_feat.High, df_feat.Low, df_feat.Close, timeperiod=14)

    df_feat['close_div_ma_5'] = df_feat['Close'] / df_feat['moving_average_5']
    df_feat['close_div_ma_15'] = df_feat['Close'] / df_feat['moving_average_15']
    df_feat['close_div_ma_60'] = df_feat['Close'] / df_feat['moving_average_60']

    df_feat['volume_div_ma_5'] = df_feat['Volume'] / df_feat['volume_moving_average_5']
    df_feat['volume_div_ma_15'] = df_feat['Volume'] / df_feat['volume_moving_average_15']
    df_feat['volume_div_ma_60'] = df_feat['Volume'] / df_feat['volume_moving_average_60']

    df_feat['close_div_ma_15_rank'] = df_feat.groupby('timestamp').close_div_ma_15.transform('rank')
    df_feat['volume_div_ma_15_rank'] = df_feat.groupby('timestamp').volume_div_ma_15.transform('rank')

    df_feat['RSI_5_rank'] = df_feat.groupby('timestamp').RSI_5.transform('rank')
    df_feat['RSI_15_rank'] = df_feat.groupby('timestamp').RSI_15.transform('rank')
    df_feat['RSI_60_rank'] = df_feat.groupby('timestamp').RSI_60.transform('rank')

    df_feat = df_feat.drop(['ln_Close', 'timestamp'], axis=1)
    
    return df_feat


def get_model_for_asset(df_train, df_test, asset_id):
    df_train = df_train[df_train["Asset_ID"] == asset_id]
    df_test = df_test[df_test["Asset_ID"] == asset_id]
    
    df_train = df_train.dropna(how="any")
    df_test = df_test.dropna(how="any")

    
    X_train, y_train = df_train.drop(['Asset_ID', 'Target'], axis=1), df_train["Target"]
    X_valid, y_valid = df_test.drop(['Asset_ID', 'Target'], axis=1), df_test["Target"]
    lgbm_train = lgbm.Dataset(X_train, y_train)
    lgbm_valid = lgbm.Dataset(X_valid, y_valid)
    weight_map_dict = dict(zip(df_asset_details['Asset_ID'], df_asset_details['Weight']))
    lgbm_train.add_w = df_train['Asset_ID'].map(weight_map_dict)
    lgbm_valid.add_w = df_test['Asset_ID'].map(weight_map_dict)
    with mlflow.start_run(experiment_id=5, nested=True):

        params = {
            "objective": "regression", 
            "metric": "l2", 
            "boosting_type": "gbdt",
            # 'early_stopping_rounds': 20,
            'learning_rate': 0.05,
            'num_leaves': 8,
            'feature_fraction': 0.5,
            'bagging_fraction': 0.5,
            'bagging_freq': 1,
            # 'extra_trees': True,
            'seed': 55
        }
        mlflow.log_params(params)

        category_feature = []
        model = lgbm.train(params=params,
            train_set=lgbm_train,
            valid_sets=[lgbm_train, lgbm_valid],
            num_boost_round=50,
            verbose_eval=10,
            feval=eval_w_corr,
            categorical_feature = category_feature,
        )
    
    return model

# %% [markdown]
# ## Loop over all assets

# %%
def weighted_correlation(a, b, weights):
  w = np.ravel(weights)
  a = np.ravel(a)
  b = np.ravel(b)

  sum_w = np.sum(w)
  mean_a = np.sum(a * w) / sum_w
  mean_b = np.sum(b * w) / sum_w
  var_a = np.sum(w * np.square(a - mean_a)) / sum_w
  var_b = np.sum(w * np.square(b - mean_b)) / sum_w

  cov = np.sum((a * b * w)) / np.sum(w) - mean_a * mean_b
  corr = cov / np.sqrt(var_a * var_b)

  return corr

# %%
df_train = get_features(df_train)
df_test = get_features(df_test)
print(df_train.columns)
# Out:
# Index(['Count', 'Open', 'High', 'Low', 'Close', 'Volume', 'VWAP', 'Asset_ID',
#        'Target', 'upper_shadow', 'lower_shadow', 'high_low_div',
#        'open_close_div', 'hlco_ration', 'log_return_1', 'log_return_5',
#        'log_return_15', 'log_return_60', 'realized_volatility_5',
#        'moving_average_5', 'moving_std_5', 'volume_moving_average_5', 'RSI_5',
#        'close_div_ma_5', 'volume_div_ma_5', 'realized_volatility_15',
#        'moving_average_15', 'moving_std_15', 'volume_moving_average_15',
#        'RSI_15', 'close_div_ma_15', 'volume_div_ma_15',
#        'realized_volatility_60', 'moving_average_60', 'moving_std_60',
#        'volume_moving_average_60', 'RSI_60', 'close_div_ma_60',
#        'volume_div_ma_60', 'close_div_ma_15_rank', 'volume_div_ma_15_rank',
#        'RSI_5_rank', 'RSI_15_rank', 'RSI_60_rank'],
#       dtype='object')

# %%
Xs = {}
ys = {}
models = {}

y_valids = []
mlflow.lightgbm.autolog()
mlflow.set_tracking_uri('../src/mlruns/')
with mlflow.start_run(experiment_id=5):
    for asset_id, asset_name in zip(df_asset_details['Asset_ID'], df_asset_details['Asset_Name']):
        print(f"Training model for {asset_name:<16} (ID={asset_id:<2})")
        
        model = get_model_for_asset(df_train, df_test, asset_id)
        models[asset_id] = model
        
        X_valid = df_test[df_test['Asset_ID'] == asset_id].drop(['Target', 'Asset_ID'], axis=1)
        y_valid = df_test.loc[df_test['Asset_ID'] == asset_id, ['Target']]
        weight_map_dict = dict(zip(df_asset_details['Asset_ID'], df_asset_details['Weight']))
        y_valid['Weight'] = weight_map_dict[asset_id]
        y_valid['Pred'] = model.predict(X_valid)
        
        y_valids.append(y_valid)
        model.save_model(os.path.join(RESULT_FOLDER, f'model{asset_id}.lgb'), num_iteration=model.best_iteration)

    y_valids = pd.concat(y_valids)

    metric = weighted_correlation(y_valids['Pred'], y_valids['Target'], y_valids['Weight'])
    print(f"overall, wcorr: {metric}")
    mlflow.log_metric('score', metric)

del X_valid, y_valid, y_valids
# Out:
# Training model for Binance Coin     (ID=0 )
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/g_research_crypto/lib/python3.7/site-packages/lightgbm/basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/g_research_crypto/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.207073 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1765347, number of used features: 42
# [LightGBM] [Info] Start training from score 0.000034
# [10]	training's l2: 3.1491e-05	training's eval_wcorr: 0.141782	valid_1's l2: 7.20706e-06	valid_1's eval_wcorr: 0.027538
# [20]	training's l2: 3.13392e-05	training's eval_wcorr: 0.158304	valid_1's l2: 7.20437e-06	valid_1's eval_wcorr: 0.0316982
# [30]	training's l2: 3.12063e-05	training's eval_wcorr: 0.171254	valid_1's l2: 7.21594e-06	valid_1's eval_wcorr: -0.00105995
# [40]	training's l2: 3.1121e-05	training's eval_wcorr: 0.179378	valid_1's l2: 7.2351e-06	valid_1's eval_wcorr: -0.033238
# [50]	training's l2: 3.10454e-05	training's eval_wcorr: 0.185779	valid_1's l2: 7.23501e-06	valid_1's eval_wcorr: -0.0256211
# Training model for Bitcoin          (ID=1 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.188195 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1811892, number of used features: 42
# [LightGBM] [Info] Start training from score -0.000002
# [10]	training's l2: 4.15835e-06	training's eval_wcorr: 0.102799	valid_1's l2: 2.52978e-06	valid_1's eval_wcorr: 0.0100248
# [20]	training's l2: 4.14795e-06	training's eval_wcorr: 0.112176	valid_1's l2: 2.53029e-06	valid_1's eval_wcorr: 0.0119011
# [30]	training's l2: 4.13791e-06	training's eval_wcorr: 0.125776	valid_1's l2: 2.52995e-06	valid_1's eval_wcorr: 0.0171128
# [40]	training's l2: 4.12978e-06	training's eval_wcorr: 0.134854	valid_1's l2: 2.53026e-06	valid_1's eval_wcorr: 0.0193719
# [50]	training's l2: 4.12337e-06	training's eval_wcorr: 0.142484	valid_1's l2: 2.5307e-06	valid_1's eval_wcorr: 0.019448
# Training model for Bitcoin Cash     (ID=2 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.182961 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1798481, number of used features: 42
# [LightGBM] [Info] Start training from score -0.000006
# [10]	training's l2: 4.31722e-05	training's eval_wcorr: 0.123921	valid_1's l2: 4.72161e-06	valid_1's eval_wcorr: -0.0111478
# [20]	training's l2: 4.29877e-05	training's eval_wcorr: 0.155098	valid_1's l2: 4.72152e-06	valid_1's eval_wcorr: 0.00171127
# [30]	training's l2: 4.2791e-05	training's eval_wcorr: 0.174251	valid_1's l2: 4.72077e-06	valid_1's eval_wcorr: 0.0102968
# [40]	training's l2: 4.26416e-05	training's eval_wcorr: 0.182739	valid_1's l2: 4.72029e-06	valid_1's eval_wcorr: 0.0153832
# [50]	training's l2: 4.24827e-05	training's eval_wcorr: 0.194816	valid_1's l2: 4.71704e-06	valid_1's eval_wcorr: 0.0302629
# Training model for Cardano          (ID=3 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.177697 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1613253, number of used features: 42
# [LightGBM] [Info] Start training from score -0.000000
# [10]	training's l2: 2.13739e-05	training's eval_wcorr: 0.0872434	valid_1's l2: 9.12016e-06	valid_1's eval_wcorr: 0.0578045
# [20]	training's l2: 2.1331e-05	training's eval_wcorr: 0.0961421	valid_1's l2: 9.11192e-06	valid_1's eval_wcorr: 0.0612833
# [30]	training's l2: 2.12989e-05	training's eval_wcorr: 0.10236	valid_1's l2: 9.10575e-06	valid_1's eval_wcorr: 0.0660057
# [40]	training's l2: 2.12688e-05	training's eval_wcorr: 0.111345	valid_1's l2: 9.10245e-06	valid_1's eval_wcorr: 0.0676617
# [50]	training's l2: 2.124e-05	training's eval_wcorr: 0.119178	valid_1's l2: 9.10145e-06	valid_1's eval_wcorr: 0.0680706
# Training model for Dogecoin         (ID=4 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.155633 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 752214, number of used features: 42
# [LightGBM] [Info] Start training from score 0.000063
# [10]	training's l2: 8.2707e-05	training's eval_wcorr: 0.173049	valid_1's l2: 1.42713e-05	valid_1's eval_wcorr: 0.0463169
# [20]	training's l2: 8.21143e-05	training's eval_wcorr: 0.20083	valid_1's l2: 1.42545e-05	valid_1's eval_wcorr: 0.0573764
# [30]	training's l2: 8.15602e-05	training's eval_wcorr: 0.223078	valid_1's l2: 1.42445e-05	valid_1's eval_wcorr: 0.0624559
# [40]	training's l2: 8.11044e-05	training's eval_wcorr: 0.238014	valid_1's l2: 1.42357e-05	valid_1's eval_wcorr: 0.0665965
# [50]	training's l2: 8.06889e-05	training's eval_wcorr: 0.245218	valid_1's l2: 1.42277e-05	valid_1's eval_wcorr: 0.0698225
# Training model for EOS.IO           (ID=5 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.189409 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1805357, number of used features: 42
# [LightGBM] [Info] Start training from score -0.000001
# [10]	training's l2: 2.43531e-05	training's eval_wcorr: 0.103179	valid_1's l2: 8.37031e-06	valid_1's eval_wcorr: 0.0609906
# [20]	training's l2: 2.42868e-05	training's eval_wcorr: 0.116335	valid_1's l2: 8.36391e-06	valid_1's eval_wcorr: 0.0610807
# [30]	training's l2: 2.42271e-05	training's eval_wcorr: 0.126761	valid_1's l2: 8.35649e-06	valid_1's eval_wcorr: 0.0667575
# [40]	training's l2: 2.41759e-05	training's eval_wcorr: 0.136263	valid_1's l2: 8.35379e-06	valid_1's eval_wcorr: 0.0672205
# [50]	training's l2: 2.41327e-05	training's eval_wcorr: 0.145169	valid_1's l2: 8.35124e-06	valid_1's eval_wcorr: 0.0689725
# Training model for Ethereum         (ID=6 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.191795 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1811744, number of used features: 42
# [LightGBM] [Info] Start training from score -0.000002
# [10]	training's l2: 6.43472e-06	training's eval_wcorr: 0.102633	valid_1's l2: 3.25671e-06	valid_1's eval_wcorr: 0.0290498
# [20]	training's l2: 6.41666e-06	training's eval_wcorr: 0.108834	valid_1's l2: 3.25647e-06	valid_1's eval_wcorr: 0.0288273
# [30]	training's l2: 6.40298e-06	training's eval_wcorr: 0.115777	valid_1's l2: 3.25497e-06	valid_1's eval_wcorr: 0.0365616
# [40]	training's l2: 6.39226e-06	training's eval_wcorr: 0.122334	valid_1's l2: 3.25486e-06	valid_1's eval_wcorr: 0.0374795
# [50]	training's l2: 6.38221e-06	training's eval_wcorr: 0.128856	valid_1's l2: 3.25473e-06	valid_1's eval_wcorr: 0.0385015
# Training model for Ethereum Classic (ID=7 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.211266 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1785567, number of used features: 42
# [LightGBM] [Info] Start training from score 0.000042
# [10]	training's l2: 8.55496e-05	training's eval_wcorr: 0.0784588	valid_1's l2: 1.08197e-05	valid_1's eval_wcorr: 0.0586678
# [20]	training's l2: 8.54051e-05	training's eval_wcorr: 0.0844197	valid_1's l2: 1.08099e-05	valid_1's eval_wcorr: 0.0597504
# [30]	training's l2: 8.52957e-05	training's eval_wcorr: 0.0911608	valid_1's l2: 1.0802e-05	valid_1's eval_wcorr: 0.063853
# [40]	training's l2: 8.52008e-05	training's eval_wcorr: 0.0982614	valid_1's l2: 1.07952e-05	valid_1's eval_wcorr: 0.066333
# [50]	training's l2: 8.51152e-05	training's eval_wcorr: 0.103566	valid_1's l2: 1.0797e-05	valid_1's eval_wcorr: 0.0600321
# Training model for IOTA             (ID=8 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.159543 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1152350, number of used features: 42
# [LightGBM] [Info] Start training from score 0.000015
# [10]	training's l2: 5.78688e-05	training's eval_wcorr: 0.134283	valid_1's l2: 0.000132521	valid_1's eval_wcorr: 0.0063107
# [20]	training's l2: 5.76606e-05	training's eval_wcorr: 0.1427	valid_1's l2: 0.000132535	valid_1's eval_wcorr: 0.00408133
# [30]	training's l2: 5.75087e-05	training's eval_wcorr: 0.147639	valid_1's l2: 0.000132542	valid_1's eval_wcorr: 0.00559851
# [40]	training's l2: 5.74045e-05	training's eval_wcorr: 0.152668	valid_1's l2: 0.000132563	valid_1's eval_wcorr: 0.00566323
# [50]	training's l2: 5.73017e-05	training's eval_wcorr: 0.159274	valid_1's l2: 0.000132561	valid_1's eval_wcorr: 0.00770399
# Training model for Litecoin         (ID=9 )
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.214550 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1810864, number of used features: 42
# [LightGBM] [Info] Start training from score -0.000014
# [10]	training's l2: 1.28481e-05	training's eval_wcorr: 0.103314	valid_1's l2: 9.11406e-06	valid_1's eval_wcorr: 0.0390252
# [20]	training's l2: 1.28109e-05	training's eval_wcorr: 0.111018	valid_1's l2: 9.10594e-06	valid_1's eval_wcorr: 0.0475131
# [30]	training's l2: 1.27827e-05	training's eval_wcorr: 0.118414	valid_1's l2: 9.10178e-06	valid_1's eval_wcorr: 0.051374
# [40]	training's l2: 1.27618e-05	training's eval_wcorr: 0.122349	valid_1's l2: 9.10446e-06	valid_1's eval_wcorr: 0.0473151
# [50]	training's l2: 1.27432e-05	training's eval_wcorr: 0.128211	valid_1's l2: 9.10048e-06	valid_1's eval_wcorr: 0.0517483
# Training model for Maker            (ID=10)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.121406 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 476411, number of used features: 42
# [LightGBM] [Info] Start training from score -0.000000
# [10]	training's l2: 3.82851e-05	training's eval_wcorr: 0.160626	valid_1's l2: 2.74522e-05	valid_1's eval_wcorr: 0.0428203
# [20]	training's l2: 3.80463e-05	training's eval_wcorr: 0.180308	valid_1's l2: 2.74327e-05	valid_1's eval_wcorr: 0.0491886
# [30]	training's l2: 3.78525e-05	training's eval_wcorr: 0.198777	valid_1's l2: 2.74227e-05	valid_1's eval_wcorr: 0.0505598
# [40]	training's l2: 3.76892e-05	training's eval_wcorr: 0.210734	valid_1's l2: 2.74135e-05	valid_1's eval_wcorr: 0.0524861
# [50]	training's l2: 3.75328e-05	training's eval_wcorr: 0.221029	valid_1's l2: 2.74091e-05	valid_1's eval_wcorr: 0.0531242
# Training model for Monero           (ID=11)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.154065 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1205282, number of used features: 42
# [LightGBM] [Info] Start training from score 0.000006
# [10]	training's l2: 4.70507e-05	training's eval_wcorr: 0.137235	valid_1's l2: 1.58131e-05	valid_1's eval_wcorr: -0.0010952
# [20]	training's l2: 4.68091e-05	training's eval_wcorr: 0.146697	valid_1's l2: 1.58186e-05	valid_1's eval_wcorr: -0.0032464
# [30]	training's l2: 4.67008e-05	training's eval_wcorr: 0.153227	valid_1's l2: 1.5817e-05	valid_1's eval_wcorr: 0.00422721
# [40]	training's l2: 4.65857e-05	training's eval_wcorr: 0.15953	valid_1's l2: 1.58193e-05	valid_1's eval_wcorr: 0.00455338
# [50]	training's l2: 4.64965e-05	training's eval_wcorr: 0.168347	valid_1's l2: 1.58206e-05	valid_1's eval_wcorr: 0.00560452
# Training model for Stellar          (ID=12)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.191102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1548076, number of used features: 42
# [LightGBM] [Info] Start training from score -0.000010
# [10]	training's l2: 2.83591e-05	training's eval_wcorr: 0.115752	valid_1's l2: 9.11732e-06	valid_1's eval_wcorr: 0.0669712
# [20]	training's l2: 2.82602e-05	training's eval_wcorr: 0.129405	valid_1's l2: 9.09851e-06	valid_1's eval_wcorr: 0.0756423
# [30]	training's l2: 2.81745e-05	training's eval_wcorr: 0.143097	valid_1's l2: 9.09604e-06	valid_1's eval_wcorr: 0.0756921
# [40]	training's l2: 2.80953e-05	training's eval_wcorr: 0.151953	valid_1's l2: 9.09789e-06	valid_1's eval_wcorr: 0.0752902
# [50]	training's l2: 2.80284e-05	training's eval_wcorr: 0.159283	valid_1's l2: 9.10283e-06	valid_1's eval_wcorr: 0.0744041
# Training model for TRON             (ID=13)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.183210 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9510
# [LightGBM] [Info] Number of data points in the train set: 1701513, number of used features: 42
# [LightGBM] [Info] Start training from score 0.000008
# [10]	training's l2: 2.5081e-05	training's eval_wcorr: 0.100276	valid_1's l2: 8.13504e-06	valid_1's eval_wcorr: 0.0342559
# [20]	training's l2: 2.50004e-05	training's eval_wcorr: 0.117129	valid_1's l2: 8.13663e-06	valid_1's eval_wcorr: 0.0223684
# [30]	training's l2: 2.49379e-05	training's eval_wcorr: 0.130521	valid_1's l2: 8.13415e-06	valid_1's eval_wcorr: 0.0285038
# [40]	training's l2: 2.48859e-05	training's eval_wcorr: 0.140717	valid_1's l2: 8.12812e-06	valid_1's eval_wcorr: 0.0406808
# [50]	training's l2: 2.48432e-05	training's eval_wcorr: 0.145342	valid_1's l2: 8.1245e-06	valid_1's eval_wcorr: 0.0457167
# overall, wcorr: 0.03847494095856221

# %%
raise ValueError("stop!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1340079/2431878494.py in <module>
# ----> 1 raise ValueError("stop!")
#
# ValueError: stop!

# %% [markdown]
# # Predict & submit
#
# References: [Detailed API Introduction](https://www.kaggle.com/sohier/detailed-api-introduction)
#
# Something that helped me understand this iterator was adding a pdb checkpoint inside of the for loop:
#
# ```python
# import pdb; pdb.set_trace()
# ```
#
# See [Python Debugging With Pdb](https://realpython.com/python-debugging-pdb/) if you want to use it and you don't know how to.

# %%
import time
history = pd.DataFrame()
max_lookback = 60

env = gresearch_crypto.make_env()
iter_test = env.iter_test()

start = time.time()
for i, (df_test, df_pred) in enumerate(iter_test):
    history = pd.concat([history, df_test]).reset_index(drop=True)

    for j , row in df_test.iterrows():
        model = models[row['Asset_ID']]
        x_test = get_features(history[history['Asset_ID'] == row['Asset_ID']]).reset_index(drop=True)
        y_pred = model.predict([x_test.iloc[-1]])[0]
        
        df_pred.loc[df_pred['row_id'] == row['row_id'], 'Target'] = y_pred
        
        # Print just one sample row to get a feeling of what it looks like
        if i == 0 and j == 0:
            display(x_test)

    # Display the first prediction dataframe
    if i == 0:
        display(df_pred)
    history = history.sort_values(by='row_id')
    history = history.iloc[-(max_lookback*14+100):]
    
    # Send submissions
    env.predict(df_pred)
end = time.time()
end-start

# %% [markdown]
# # df_train and df_test overlap

# %%
# df_test = pd.concat(all_df_test)
# df_test['datetime'] = pd.to_datetime(df_test['timestamp'], unit='s')
# df_train['datetime'] = pd.to_datetime(df_train['timestamp'], unit='s')

# %%
# df_train['datetime'].max()

# %%
# df_test['datetime'].min()
