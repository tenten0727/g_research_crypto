# %%
import talib

# %%
import pandas as pd 
data_path = '../input/'
train = pd.read_pickle(data_path+'/train.pkl')
train.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 4  1514764860         7    5.0     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8770   121.087310     25.891363 -0.008264

# %%
train['ema'] = train.groupby('Asset_ID').Close.transform(lambda x: talib.EMA(x))

# %%
train[train.Asset_ID==0].describe()
# Out:
#           timestamp   Asset_ID         Count          Open          High  \
# count  1.942619e+06  1942619.0  1.942619e+06  1.942619e+06  1.942619e+06
# mean   1.573678e+09        0.0  1.864472e+02  7.693521e+01  7.703386e+01
# std    3.388205e+07        0.0  4.368002e+02  1.405713e+02  1.407604e+02
# min    1.514765e+09        0.0  1.000000e+00  4.127000e+00  4.139800e+00
# 25%    1.544434e+09        0.0  1.800000e+01  1.302450e+01  1.303890e+01
# 50%    1.573812e+09        0.0  4.500000e+01  1.815500e+01  1.816850e+01
# 75%    1.603023e+09        0.0  1.530000e+02  3.077380e+01  3.079855e+01
# max    1.632182e+09        0.0  3.205300e+04  6.911170e+02  6.917700e+02
#
#                 Low         Close        Volume          VWAP        Target  \
# count  1.942619e+06  1.942619e+06  1.942619e+06  1.942619e+06  1.929204e+06
# mean   7.683172e+01  7.693510e+01  1.861112e+03  7.693310e+01  3.183935e-05
# std    1.403731e+02  1.405703e+02  2.899794e+03  1.405683e+02  5.451780e-03
# ...

# %%
for id in train.Asset_ID.unique():
# ADX - Average Directional Movement Index (平均方向性指数)
# トレンドの存在を確認するための指標
    x = train[train.Asset_ID==id]
    train.loc[train.Asset_ID==id, 'adx'] = talib.ADX(x.High, x.Low, x.Close, timeperiod=14)

train
# Out:
#            timestamp  Asset_ID  Count          Open          High  \
# 0         1514764860         2   40.0   2376.580000   2399.500000
# 1         1514764860         0    5.0      8.530000      8.530000
# 2         1514764860         1  229.0  13835.194000  14013.800000
# 3         1514764860         5   32.0      7.659600      7.659600
# 4         1514764860         7    5.0     25.920000     25.920000
# ...              ...       ...    ...           ...           ...
# 24236801  1632182400         9  775.0    157.181571    157.250000
# 24236802  1632182400        10   34.0   2437.065067   2438.000000
# 24236803  1632182400        13  380.0      0.091390      0.091527
# 24236804  1632182400        12  177.0      0.282168      0.282438
# 24236805  1632182400        11   48.0    232.695000    232.800000
#
#                    Low         Close        Volume          VWAP    Target  \
# 0          2357.140000   2374.590000  1.923301e+01   2373.116392 -0.004218
# ...
