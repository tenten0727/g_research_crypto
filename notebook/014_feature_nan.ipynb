# %%
import sys 
sys.path.append('../src')
from feature_base import load_datasets
import glob
FEATURE_FOLDER = '../features'

feats = glob.glob(FEATURE_FOLDER+'/**.pkl')
data = load_datasets(feats)
data.head()
# Out:
#    moving_average_15  moving_std_15  volume_moving_average_15  RSI_15  \
# 0         158.306000            NaN                  1.282200     NaN
# 1           0.568667            NaN                  5.225333     NaN
# 2         923.345067            NaN                  2.103337     NaN
# 3           0.510507            NaN                441.780891     NaN
# 4           1.725133            NaN                  8.072487     NaN
#
#    moving_average_60  moving_std_60  volume_moving_average_60  RSI_60  \
# 0          39.576500            NaN                  0.320550     NaN
# 1           0.142167            NaN                  1.306333     NaN
# 2         230.836267            NaN                  0.525834     NaN
# 3           0.127627            NaN                110.445223     NaN
# 4           0.431283            NaN                  2.018122     NaN
#
#    close_div_ma_60  high_low_div  ...  Asset_ID  Count        Open  \
# 0             60.0      1.017971  ...         2   40.0   2376.5800
# 1             60.0      1.000000  ...         0    5.0      8.5300
# 2             60.0      1.025442  ...         1  229.0  13835.1940
# 3             60.0      1.000379  ...         5   32.0      7.6596
# 4             60.0      1.001778  ...         7    5.0     25.9200
#
#          High         Low       Close       Volume          VWAP    Target  \
# 0   2399.5000   2357.1400   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300      8.5300      8.5300    78.380000      8.530000 -0.014399
# 2  14013.8000  13666.1100  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6596      7.6567      7.6576  6626.713370      7.657713 -0.013922
# 4     25.9200     25.8740     25.8770   121.087310     25.891363 -0.008264
#
#              datetime
# 0 2018-01-01 00:01:00
# 1 2018-01-01 00:01:00
# 2 2018-01-01 00:01:00
# 3 2018-01-01 00:01:00
# 4 2018-01-01 00:01:00
#
# [5 rows x 41 columns]

# %%
data.isna().sum().sort_values(ascending=False)
# Out:
# Target                         750338
# hlco_ration                    723142
# ht_trendline                      882
# RSI_60                            840
# MACD_hist                         462
# MACD_signal                       462
# MACD                              462
# adx                               378
# w_raw_return_causal               210
# raw_return_causal                 210
# Close_diff1_rank                  210
# raw_market_return_causal          210
# RSI_15                            210
# beta_causal                       119
# moving_std_15                      14
# moving_std_60                      14
# VWAP                                9
# Count                               0
# market_return_causal_square         0
# Open                                0
# High                                0
# Low                                 0
# Close                               0
# Volume                              0
# Asset_ID                            0
# timestamp                           0
# moving_average_15                   0
# Lower_Shadow                        0
# market_return_causal                0
# Weight                              0
# ln_Close                            0
# Upper_Shadow                        0
# high_low_sub                        0
# open_close_sub                      0
# open_close_div                      0
# high_low_div                        0
# close_div_ma_60                     0
# volume_moving_average_60            0
# moving_average_60                   0
# volume_moving_average_15            0
# datetime                            0
# dtype: int64
