# %%
import sys 
sys.path.append('../src')
from feature_base import load_datasets
import glob
FEATURE_FOLDER = '../features'

feats = glob.glob(FEATURE_FOLDER+'/**.pkl')
data = load_datasets(feats)
data.head()
# Out:
#    moving_average_5  moving_std_5  volume_moving_average_5  RSI_5  \
# 0         474.91800           NaN                 3.846601    NaN
# 1           1.70600           NaN                15.676000    NaN
# 2        2770.03520           NaN                 6.310012    NaN
# 3           1.53152           NaN              1325.342674    NaN
# 4           5.17540           NaN                24.217462    NaN
#
#    moving_average_15  moving_std_15  volume_moving_average_15  RSI_15  \
# 0         158.306000            NaN                  1.282200     NaN
# 1           0.568667            NaN                  5.225333     NaN
# 2         923.345067            NaN                  2.103337     NaN
# 3           0.510507            NaN                441.780891     NaN
# 4           1.725133            NaN                  8.072487     NaN
#
#    moving_average_60  moving_std_60  ...         Low       Close       Volume  \
# ...

# %%
data.isna().sum().sort_values(ascending=False)
# Out:
# Target                         750338
# hlco_ration                    723142
# RSI_60                            840
# MACD_hist                         462
# MACD_signal                       462
# MACD                              462
# adx                               378
# realized_volatility_15            210
# Close_diff1_rank                  210
# raw_market_return_causal          210
# w_raw_return_causal               210
# raw_return_causal                 210
# RV_15_rank                        210
# RSI_15                            210
# beta_causal                       119
# RSI_5                              70
# moving_std_60                      14
# log_return_1                       14
# moving_std_15                      14
# moving_std_5                       14
# VWAP                                9
# close_div_ma_15                     0
# moving_average_15                   0
# timestamp                           0
# Asset_ID                            0
# ...

# %%
test = data[data.datetime >= '2021-06-13 00:00:00']
test
# Out:
#           moving_average_5  moving_std_5  volume_moving_average_5      RSI_5  \
# 22221694          1.479042      0.002660             3.517003e+05  77.362107
# 22221695        580.194733      1.200809             3.518572e+02  76.613615
# 22221696        343.575600      0.621865             1.128419e+03  70.164850
# 22221697      35521.589091     59.338085             1.021744e+02  68.269556
# 22221698          0.311929      0.000241             7.577482e+05  56.298811
# ...                    ...           ...                      ...        ...
# 24236801        156.809571      0.395349             2.004685e+03  49.859647
# 24236802       2426.988343      7.123586             4.203100e+00  57.611476
# 24236803          0.091124      0.000244             3.347923e+06  58.297421
# 24236804          0.281477      0.000722             2.502319e+05  55.637040
# 24236805        231.791100      0.538690             9.524711e+01  55.028428
#
# ...

# %%
test['null'] = test.Target.isnull()
# Out:
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/g_research_crypto/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

train = data[data.datetime < '2021-06-13 00:00:00']
train['null'] = train.Target.null()

for i in train.Asset_ID.unique():
    print('Asset', i)
    asset_train = train[train.Asset_ID==i]

    sns.relplot(x='datetime', y='null', data=asset_train, kind='line')

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_940391/2803270711.py in <module>
#       3
#       4 train = data[data.datetime < '2021-06-13 00:00:00']
# ----> 5 train['null'] = train.Target.null()
#       6
#       7 for i in train.Asset_ID.unique():
#
# ~/.pyenv/versions/3.7.10/envs/g_research_crypto/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'null'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for i in test.Asset_ID.unique():
    print('Asset', i)
    asset_test = test[test.Asset_ID==i]

    sns.relplot(x='datetime', y='null', data=asset_test, kind='line')

    plt.show()
# Out:
# Asset 3
# Asset 2
# Asset 0
# Asset 1
# Asset 4
# Asset 5
# Asset 7
# Asset 6
# Asset 8
# Asset 9
# Asset 10
# Asset 13
# Asset 12
# Asset 11

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for i in test.Asset_ID.unique():
    asset_test = test[test.Asset_ID==i]

    sns.relplot(x='datetime', y='Target', data=asset_test, kind='line')

    plt.show()
